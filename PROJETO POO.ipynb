# %%
class Aluno:
    def __init__(self, nome,matricula):
    ## atributos privados :
        self.__nome = None
        self.__matricula = None
        self.__notas = []

        self. set_nome(nome)
        self.set_matricula(matricula)

## getter para o nome
    def get_nome(self):
        return self.__nome

## setter para o nome , com validação : não pode ser vazio ou conter apanas espaços 
 
    def set_nome(self, nome):
        if nome: # verifica se o nome não é  vazio ou apenas espaços
            self.__nome = nome
        else:
            print("nome invalido. Por favor, insira um nome valido. ")

## getter para a matricula
    def get_matricula (self):
        return self.__matricula

    ## setter para matricula com validação : número entre 8 e 10 digitos 
    def set_matricula(self, matricula):
        if matricula.isdigit() and 8 <= len(matricula) <= 10 :
            self.__matricula = matricula
        else:
            print("matricula inválida. deve conter entre 8 e 10 digitos numéricos.")

    def adicionar_nota (self, nota):
        if 0 <= nota <= 10 :
            self.__notas.append(nota)
        else:
            print("nota inválida!")

    def calcular_media (self): ## retorna a média das notas do aluno ou 0 se houver notas.
        if len(self.__notas) == 0 :
            return 0
        return sum (self.__notas)/ len(self.__notas)   

    def mostrar_dados(self):
        print("nome:", self.get_nome())
        print("matricula:", self.get_matricula())
        print("media:", self.calcular_media())
        print("-" * 30)

# %%
aluno1 = Aluno("João", "2025101035")
aluno1.adicionar_nota(8.0)
aluno1.adicionar_nota(7.0)

print("Aluno:", aluno1.get_nome())
print("Média:", aluno1.calcular_media())
# Out:
# Aluno: João
# Média: 7.5

# %%
# Criando dois alunos
aluno1 = Aluno("Maria", "12345678")
aluno2 = Aluno("João", "87654321")

# Adicionando notas diferentes
aluno1.adicionar_nota(8)
aluno1.adicionar_nota(9)
aluno1.adicionar_nota(7)

aluno2.adicionar_nota(5)
aluno2.adicionar_nota(6)
aluno2.adicionar_nota(7)

# Mostrando os dados
aluno1.mostrar_dados()
aluno2.mostrar_dados()
# Adicionando notas diferentes
aluno1.adicionar_nota(8)
aluno1.adicionar_nota(9)
aluno1.adicionar_nota(7)

aluno2.adicionar_nota(5)
aluno2.adicionar_nota(6)
aluno2.adicionar_nota(7)

# Mostrando os dados
aluno1.mostrar_dados()
aluno2.mostrar_dados()
# Out:
# nome: Maria
# matricula: 12345678
# media: 8.0
# ------------------------------
# nome: João
# matricula: 87654321
# media: 6.0
# ------------------------------
